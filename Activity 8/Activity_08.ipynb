# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread ('pikachu.jpeg',1) 
from google.colab.patches import cv2_imshow
cv2_imshow(img)
print()
# Converting color image to grayscale image
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=RGB size=168x300 at 0x7F5E8D9F0160>
# <PIL.Image.Image image mode=L size=168x300 at 0x7F5E8E637C70>
