# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("salary_data.csv")
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
viz = pd.read_csv("salary_data.csv") 
viz.hist()
# Out:
# array([[<Axes: title={'center': 'YearsExperience'}>,
#         <Axes: title={'center': 'Salary'}>]], dtype=object)

# %%
plt.scatter(df.YearsExperience  , df.Salary,  color='red')
plt.xlabel("YEARS OF EXPERIENCE")
plt.ylabel("SALARY")
plt.show()

# %%
from sklearn import linear_model
train =  pd.read_csv("salary_data.csv") 

regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['YearsExperience']])
train_y = np.asanyarray(train[['Salary']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[9449.96232146]]
# Intercept:  [25792.20019867]

# %%
import matplotlib.pyplot as plt
plt.scatter(df.YearsExperience  , df.Salary,   color='green')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("YEARS OF EXPERIENCE")
plt.ylabel("SALARY")
plt.show()

# %%
from sklearn.metrics import r2_score
test = pd.read_csv("salary_data.csv") 
test_x = np.asanyarray(test[['YearsExperience']])
test_y = np.asanyarray(test[['Salary']])
test_y_hat = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )
# Out:
# Mean absolute error: 4644.20
# Residual sum of squares (MSE): 31270951.72
# R2-score: 0.96

# %%
import seaborn as sns
ax = sns.distplot(test_y, color = 'g', label="true-values", hist=False)
sns.distplot(test_y_hat, color='b', label="predicted values", hist= False , ax = ax)
plt.show()
# Out:
# <ipython-input-26-10252b84f54f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(test_y, color = 'g', label="true-values", hist=False)
# <ipython-input-26-10252b84f54f>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.pairplot(df, kind="reg")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['YearsExperience']])
y = np.asanyarray(train[['Salary']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[9449.96232146]]
